# %%
from zipfile import ZipFile
with ZipFile('/content/chigrtka.zip',mode='r') as zip:
  zip.extractall()
print('done')
# Out:
# done

# %%
import os

# Open a file
path = "/content/animal/train_data/images/val"
dirs = os.listdir( path )
s = 0
for file in dirs:
   s+=1
s
# Out:
# 101

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install
import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v7.0-38-g4362372 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.8/78.2 GB disk)

# %%
# !python train.py --img 640 --batch 16 --epochs 60 --data custom.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=60, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-38-g4362372 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/train_data/labels/train... 0 images, 24 backgrounds, 542 corrupt: 100% 566/566 [00:39<00:00, 14.38it/s]
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_120531.jpg: ignoring corrupt image/label: image file is truncated (82 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_120613.jpg: ignoring corrupt image/label: image file is truncated (94 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_120711.jpg: ignoring corrupt image/label: image file is truncated (131 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_120744.jpg: ignoring corrupt image/label: image file is truncated (14 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_120831.jpg: ignoring corrupt image/label: image file is truncated (63 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_120903.jpg: ignoring corrupt image/label: image file is truncated (8 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_120929.jpg: ignoring corrupt image/label: image file is truncated (127 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_121001.jpg: ignoring corrupt image/label: image file is truncated (90 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_121032.jpg: ignoring corrupt image/label: image file is truncated (74 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_121055.jpg: ignoring corrupt image/label: image file is truncated (57 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_121122.jpg: ignoring corrupt image/label: image file is truncated (106 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_121137.jpg: ignoring corrupt image/label: image file is truncated (82 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_121215.jpg: ignoring corrupt image/label: image file is truncated (54 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_121243.jpg: ignoring corrupt image/label: image file is truncated (20 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_121309.jpg: ignoring corrupt image/label: image file is truncated (43 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_121332.jpg: ignoring corrupt image/label: image file is truncated (9 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_121357.jpg: ignoring corrupt image/label: image file is truncated (110 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_144838.jpg: ignoring corrupt image/label: image file is truncated (86 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_144938.jpg: ignoring corrupt image/label: image file is truncated (48 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_145026.jpg: ignoring corrupt image/label: image file is truncated (85 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_145119.jpg: ignoring corrupt image/label: image file is truncated (47 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_145145.jpg: ignoring corrupt image/label: image file is truncated (1 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_145232.jpg: ignoring corrupt image/label: image file is truncated (29 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_145250.jpg: ignoring corrupt image/label: image file is truncated (100 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_145323.jpg: ignoring corrupt image/label: image file is truncated (23 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_145358.jpg: ignoring corrupt image/label: image file is truncated (68 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_145423.jpg: ignoring corrupt image/label: image file is truncated (39 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_145456.jpg: ignoring corrupt image/label: image file is truncated (36 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_145527.jpg: ignoring corrupt image/label: image file is truncated (12 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_145638.jpg: ignoring corrupt image/label: image file is truncated (24 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_145709.jpg: ignoring corrupt image/label: image file is truncated (14 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_145738.jpg: ignoring corrupt image/label: image file is truncated (86 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_145836.jpg: ignoring corrupt image/label: image file is truncated (32 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_145905.jpg: ignoring corrupt image/label: image file is truncated (47 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_145952.jpg: ignoring corrupt image/label: image file is truncated (33 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_150019.jpg: ignoring corrupt image/label: image file is truncated (92 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_150055.jpg: ignoring corrupt image/label: image file is truncated (26 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_150122.jpg: ignoring corrupt image/label: image file is truncated (21 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_150208.jpg: ignoring corrupt image/label: image file is truncated (32 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_150311.jpg: ignoring corrupt image/label: image file is truncated (10 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_150342.jpg: ignoring corrupt image/label: image file is truncated (16 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_150416.jpg: ignoring corrupt image/label: image file is truncated (101 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_150441.jpg: ignoring corrupt image/label: image file is truncated (54 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_150441_1.jpg: ignoring corrupt image/label: image file is truncated (37 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_150459.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_150516.jpg: ignoring corrupt image/label: image file is truncated (26 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_150529.jpg: ignoring corrupt image/label: image file is truncated (32 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_150554.jpg: ignoring corrupt image/label: image file is truncated (5 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_150619.jpg: ignoring corrupt image/label: image file is truncated (120 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_150647.jpg: ignoring corrupt image/label: image file is truncated (30 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_150722.jpg: ignoring corrupt image/label: image file is truncated (5 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180811_150744.jpg: ignoring corrupt image/label: image file is truncated (25 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_094526.jpg: ignoring corrupt image/label: image file is truncated (15 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_094605.jpg: ignoring corrupt image/label: image file is truncated (105 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_094627.jpg: ignoring corrupt image/label: image file is truncated (49 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_094648.jpg: ignoring corrupt image/label: image file is truncated (30 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_094726.jpg: ignoring corrupt image/label: image file is truncated (53 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_094806.jpg: ignoring corrupt image/label: image file is truncated (1 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_094828.jpg: ignoring corrupt image/label: image file is truncated (79 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_095101.jpg: ignoring corrupt image/label: image file is truncated (57 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_095133.jpg: ignoring corrupt image/label: image file is truncated (9 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_095152.jpg: ignoring corrupt image/label: image file is truncated (20 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_095234.jpg: ignoring corrupt image/label: image file is truncated (85 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_095309.jpg: ignoring corrupt image/label: image file is truncated (37 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_095326.jpg: ignoring corrupt image/label: image file is truncated (47 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_095425.jpg: ignoring corrupt image/label: image file is truncated (58 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_095459.jpg: ignoring corrupt image/label: image file is truncated (31 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_095522.jpg: ignoring corrupt image/label: image file is truncated (24 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_095554.jpg: ignoring corrupt image/label: image file is truncated (95 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_095636.jpg: ignoring corrupt image/label: image file is truncated (65 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_095710.jpg: ignoring corrupt image/label: image file is truncated (102 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_095735.jpg: ignoring corrupt image/label: image file is truncated (111 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_095803.jpg: ignoring corrupt image/label: image file is truncated (89 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_095834.jpg: ignoring corrupt image/label: image file is truncated (56 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_100016.jpg: ignoring corrupt image/label: image file is truncated (133 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_100103.jpg: ignoring corrupt image/label: image file is truncated (31 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_100141.jpg: ignoring corrupt image/label: image file is truncated (75 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_100317.jpg: ignoring corrupt image/label: image file is truncated (49 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_100336.jpg: ignoring corrupt image/label: image file is truncated (102 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_100415.jpg: ignoring corrupt image/label: image file is truncated (26 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_100447.jpg: ignoring corrupt image/label: image file is truncated (7 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_100508.jpg: ignoring corrupt image/label: image file is truncated (3 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_100548.jpg: ignoring corrupt image/label: image file is truncated (129 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_100609.jpg: ignoring corrupt image/label: image file is truncated (7 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_100630.jpg: ignoring corrupt image/label: image file is truncated (74 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_100719.jpg: ignoring corrupt image/label: image file is truncated (45 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_100746.jpg: ignoring corrupt image/label: image file is truncated (30 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_100822.jpg: ignoring corrupt image/label: image file is truncated (24 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_100856.jpg: ignoring corrupt image/label: image file is truncated (98 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_100913.jpg: ignoring corrupt image/label: image file is truncated (64 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_100940.jpg: ignoring corrupt image/label: image file is truncated (36 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_101009.jpg: ignoring corrupt image/label: image file is truncated (34 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_101108.jpg: ignoring corrupt image/label: image file is truncated (9 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_101145.jpg: ignoring corrupt image/label: image file is truncated (2 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_101206.jpg: ignoring corrupt image/label: image file is truncated (59 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_101225.jpg: ignoring corrupt image/label: image file is truncated (58 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_101325.jpg: ignoring corrupt image/label: image file is truncated (111 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_101355.jpg: ignoring corrupt image/label: image file is truncated (80 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_101421.jpg: ignoring corrupt image/label: image file is truncated (23 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_101453.jpg: ignoring corrupt image/label: image file is truncated (17 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_101538.jpg: ignoring corrupt image/label: image file is truncated (49 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_101604.jpg: ignoring corrupt image/label: image file is truncated (22 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_101640.jpg: ignoring corrupt image/label: image file is truncated (75 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_101700.jpg: ignoring corrupt image/label: image file is truncated (30 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_101743.jpg: ignoring corrupt image/label: image file is truncated (18 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_101807.jpg: ignoring corrupt image/label: image file is truncated (8 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_101849.jpg: ignoring corrupt image/label: image file is truncated (26 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_101912.jpg: ignoring corrupt image/label: image file is truncated (72 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_101934.jpg: ignoring corrupt image/label: image file is truncated (65 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_102008.jpg: ignoring corrupt image/label: image file is truncated (29 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_102041.jpg: ignoring corrupt image/label: image file is truncated (50 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_102151.jpg: ignoring corrupt image/label: image file is truncated (77 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_102213.jpg: ignoring corrupt image/label: image file is truncated (5 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_102240.jpg: ignoring corrupt image/label: image file is truncated (58 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_102315.jpg: ignoring corrupt image/label: image file is truncated (31 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_102405.jpg: ignoring corrupt image/label: image file is truncated (59 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_102440.jpg: ignoring corrupt image/label: image file is truncated (20 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_102505.jpg: ignoring corrupt image/label: image file is truncated (3 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_102540.jpg: ignoring corrupt image/label: image file is truncated (5 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_102615.jpg: ignoring corrupt image/label: image file is truncated (104 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_102647.jpg: ignoring corrupt image/label: image file is truncated (85 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_102727.jpg: ignoring corrupt image/label: image file is truncated (33 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_102808.jpg: ignoring corrupt image/label: image file is truncated (10 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_102902.jpg: ignoring corrupt image/label: image file is truncated (42 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_102959.jpg: ignoring corrupt image/label: image file is truncated (110 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_103033.jpg: ignoring corrupt image/label: image file is truncated (22 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_103109.jpg: ignoring corrupt image/label: image file is truncated (103 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_103846.jpg: ignoring corrupt image/label: image file is truncated (78 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_103905.jpg: ignoring corrupt image/label: image file is truncated (67 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_103906.jpg: ignoring corrupt image/label: image file is truncated (10 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_103936.jpg: ignoring corrupt image/label: image file is truncated (50 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104007.jpg: ignoring corrupt image/label: image file is truncated (54 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104009.jpg: ignoring corrupt image/label: image file is truncated (80 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104046.jpg: ignoring corrupt image/label: image file is truncated (79 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104107.jpg: ignoring corrupt image/label: image file is truncated (48 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104128.jpg: ignoring corrupt image/label: image file is truncated (126 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104201.jpg: ignoring corrupt image/label: image file is truncated (72 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104232.jpg: ignoring corrupt image/label: image file is truncated (24 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104256.jpg: ignoring corrupt image/label: image file is truncated (110 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104320.jpg: ignoring corrupt image/label: image file is truncated (5 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104343.jpg: ignoring corrupt image/label: image file is truncated (13 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104430.jpg: ignoring corrupt image/label: image file is truncated (35 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104502.jpg: ignoring corrupt image/label: image file is truncated (98 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104543.jpg: ignoring corrupt image/label: image file is truncated (59 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104612.jpg: ignoring corrupt image/label: image file is truncated (18 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104628.jpg: ignoring corrupt image/label: image file is truncated (76 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104650.jpg: ignoring corrupt image/label: image file is truncated (60 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104730.jpg: ignoring corrupt image/label: image file is truncated (154 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104751.jpg: ignoring corrupt image/label: image file is truncated (67 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104808.jpg: ignoring corrupt image/label: image file is truncated (28 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104835.jpg: ignoring corrupt image/label: image file is truncated (120 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104920.jpg: ignoring corrupt image/label: image file is truncated (66 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_104944.jpg: ignoring corrupt image/label: image file is truncated (10 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105019.jpg: ignoring corrupt image/label: image file is truncated (36 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105101.jpg: ignoring corrupt image/label: image file is truncated (41 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105116.jpg: ignoring corrupt image/label: image file is truncated (44 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105203.jpg: ignoring corrupt image/label: image file is truncated (2 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105221.jpg: ignoring corrupt image/label: image file is truncated (43 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105243.jpg: ignoring corrupt image/label: image file is truncated (25 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105310.jpg: ignoring corrupt image/label: image file is truncated (1 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105331.jpg: ignoring corrupt image/label: image file is truncated (27 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105400.jpg: ignoring corrupt image/label: image file is truncated (76 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105422.jpg: ignoring corrupt image/label: image file is truncated (21 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105441.jpg: ignoring corrupt image/label: image file is truncated (99 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105508.jpg: ignoring corrupt image/label: image file is truncated (82 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105530.jpg: ignoring corrupt image/label: image file is truncated (97 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105601.jpg: ignoring corrupt image/label: image file is truncated (59 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105620.jpg: ignoring corrupt image/label: image file is truncated (71 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105649.jpg: ignoring corrupt image/label: image file is truncated (78 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105707.jpg: ignoring corrupt image/label: image file is truncated (93 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105734.jpg: ignoring corrupt image/label: image file is truncated (36 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105810.jpg: ignoring corrupt image/label: image file is truncated (3 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105836.jpg: ignoring corrupt image/label: image file is truncated (52 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105855.jpg: ignoring corrupt image/label: image file is truncated (79 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105916.jpg: ignoring corrupt image/label: image file is truncated (46 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_105940.jpg: ignoring corrupt image/label: image file is truncated (34 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110004.jpg: ignoring corrupt image/label: image file is truncated (89 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110045.jpg: ignoring corrupt image/label: image file is truncated (21 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110108.jpg: ignoring corrupt image/label: image file is truncated (10 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110150.jpg: ignoring corrupt image/label: image file is truncated (35 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110210.jpg: ignoring corrupt image/label: image file is truncated (30 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110238.jpg: ignoring corrupt image/label: image file is truncated (2 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110310.jpg: ignoring corrupt image/label: image file is truncated (36 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110330.jpg: ignoring corrupt image/label: image file is truncated (74 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110351.jpg: ignoring corrupt image/label: image file is truncated (64 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110417.jpg: ignoring corrupt image/label: image file is truncated (51 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110447.jpg: ignoring corrupt image/label: image file is truncated (35 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110513.jpg: ignoring corrupt image/label: image file is truncated (37 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110536.jpg: ignoring corrupt image/label: image file is truncated (102 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110556.jpg: ignoring corrupt image/label: image file is truncated (143 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110615.jpg: ignoring corrupt image/label: image file is truncated (26 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110637.jpg: ignoring corrupt image/label: image file is truncated (85 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110704.jpg: ignoring corrupt image/label: image file is truncated (89 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110730.jpg: ignoring corrupt image/label: image file is truncated (74 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110751.jpg: ignoring corrupt image/label: image file is truncated (79 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110812.jpg: ignoring corrupt image/label: image file is truncated (31 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110831.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110851.jpg: ignoring corrupt image/label: image file is truncated (49 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110917.jpg: ignoring corrupt image/label: image file is truncated (9 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110931.jpg: ignoring corrupt image/label: image file is truncated (11 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_110958.jpg: ignoring corrupt image/label: image file is truncated (73 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_111016.jpg: ignoring corrupt image/label: image file is truncated (70 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_111034.jpg: ignoring corrupt image/label: image file is truncated (104 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_111057.jpg: ignoring corrupt image/label: image file is truncated (28 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_111148.jpg: ignoring corrupt image/label: image file is truncated (56 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_111205.jpg: ignoring corrupt image/label: image file is truncated (50 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_111222.jpg: ignoring corrupt image/label: image file is truncated (56 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_111248.jpg: ignoring corrupt image/label: image file is truncated (82 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_111306.jpg: ignoring corrupt image/label: image file is truncated (57 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_111332.jpg: ignoring corrupt image/label: image file is truncated (24 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_111409.jpg: ignoring corrupt image/label: image file is truncated (4 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_111431.jpg: ignoring corrupt image/label: image file is truncated (15 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_111456.jpg: ignoring corrupt image/label: image file is truncated (12 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_111518.jpg: ignoring corrupt image/label: image file is truncated (67 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180812_111547.jpg: ignoring corrupt image/label: image file is truncated (1 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_093802.jpg: ignoring corrupt image/label: image file is truncated (47 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_093843.jpg: ignoring corrupt image/label: image file is truncated (45 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_093850.jpg: ignoring corrupt image/label: image file is truncated (37 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_094027.jpg: ignoring corrupt image/label: image file is truncated (28 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_094045.jpg: ignoring corrupt image/label: image file is truncated (166 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_094219.jpg: ignoring corrupt image/label: image file is truncated (100 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_094234.jpg: ignoring corrupt image/label: image file is truncated (44 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_094242.jpg: ignoring corrupt image/label: image file is truncated (74 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_094250.jpg: ignoring corrupt image/label: image file is truncated (37 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_094256.jpg: ignoring corrupt image/label: image file is truncated (68 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_094258.jpg: ignoring corrupt image/label: image file is truncated (134 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_094430.jpg: ignoring corrupt image/label: image file is truncated (58 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_094448.jpg: ignoring corrupt image/label: image file is truncated (60 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_094458.jpg: ignoring corrupt image/label: image file is truncated (1 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_094544.jpg: ignoring corrupt image/label: image file is truncated (54 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_094621.jpg: ignoring corrupt image/label: image file is truncated (29 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_094626.jpg: ignoring corrupt image/label: image file is truncated (104 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_094637.jpg: ignoring corrupt image/label: image file is truncated (5 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_094643.jpg: ignoring corrupt image/label: image file is truncated (101 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_094644.jpg: ignoring corrupt image/label: image file is truncated (23 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_094700.jpg: ignoring corrupt image/label: image file is truncated (24 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_094755.jpg: ignoring corrupt image/label: image file is truncated (107 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_094935.jpg: ignoring corrupt image/label: image file is truncated (156 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_095105.jpg: ignoring corrupt image/label: image file is truncated (59 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_095120_BURST001_COVER.jpg: ignoring corrupt image/label: image file is truncated (93 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_095120_BURST002.jpg: ignoring corrupt image/label: image file is truncated (41 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_095124.jpg: ignoring corrupt image/label: image file is truncated (106 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_095133.jpg: ignoring corrupt image/label: image file is truncated (124 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_095433.jpg: ignoring corrupt image/label: image file is truncated (32 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_095437.jpg: ignoring corrupt image/label: image file is truncated (110 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_095503_BURST001_COVER.jpg: ignoring corrupt image/label: image file is truncated (173 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_095503_BURST002.jpg: ignoring corrupt image/label: image file is truncated (71 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_095503_BURST003.jpg: ignoring corrupt image/label: image file is truncated (69 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_095503_BURST004.jpg: ignoring corrupt image/label: image file is truncated (68 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_095503_BURST005.jpg: ignoring corrupt image/label: image file is truncated (138 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_095828.jpg: ignoring corrupt image/label: image file is truncated (54 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_095837.jpg: ignoring corrupt image/label: image file is truncated (38 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_100020.jpg: ignoring corrupt image/label: image file is truncated (24 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_100023.jpg: ignoring corrupt image/label: image file is truncated (1 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_100036.jpg: ignoring corrupt image/label: image file is truncated (48 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_100206.jpg: ignoring corrupt image/label: image file is truncated (113 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_100259.jpg: ignoring corrupt image/label: image file is truncated (30 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_100300.jpg: ignoring corrupt image/label: image file is truncated (10 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_100319.jpg: ignoring corrupt image/label: image file is truncated (162 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_100324.jpg: ignoring corrupt image/label: image file is truncated (100 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_100529.jpg: ignoring corrupt image/label: image file is truncated (34 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_101351.jpg: ignoring corrupt image/label: image file is truncated (100 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_101503.jpg: ignoring corrupt image/label: image file is truncated (35 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_101504.jpg: ignoring corrupt image/label: image file is truncated (56 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_101550.jpg: ignoring corrupt image/label: image file is truncated (99 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_101619.jpg: ignoring corrupt image/label: image file is truncated (31 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_101644.jpg: ignoring corrupt image/label: image file is truncated (68 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_101650.jpg: ignoring corrupt image/label: image file is truncated (12 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_101701.jpg: ignoring corrupt image/label: image file is truncated (14 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_101830.jpg: ignoring corrupt image/label: image file is truncated (116 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_101902.jpg: ignoring corrupt image/label: image file is truncated (41 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_101922.jpg: ignoring corrupt image/label: image file is truncated (156 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_102039.jpg: ignoring corrupt image/label: image file is truncated (38 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_102305.jpg: ignoring corrupt image/label: image file is truncated (17 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_102312.jpg: ignoring corrupt image/label: image file is truncated (15 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_102320.jpg: ignoring corrupt image/label: image file is truncated (50 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180813_102338.jpg: ignoring corrupt image/label: image file is truncated (19 bytes not processed)
# ...
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_114554.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_114755.jpg: ignoring corrupt image/label: image file is truncated (30 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_114828.jpg: ignoring corrupt image/label: image file is truncated (42 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_115229.jpg: ignoring corrupt image/label: image file is truncated (124 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_115520.jpg: ignoring corrupt image/label: image file is truncated (0 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_115612.jpg: ignoring corrupt image/label: image file is truncated (40 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_115736.jpg: ignoring corrupt image/label: image file is truncated (84 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_115812.jpg: ignoring corrupt image/label: image file is truncated (46 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_120216.jpg: ignoring corrupt image/label: image file is truncated (109 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_121254.jpg: ignoring corrupt image/label: image file is truncated (100 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_121529.jpg: ignoring corrupt image/label: image file is truncated (43 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_121657.jpg: ignoring corrupt image/label: image file is truncated (43 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_121934.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_121945.jpg: ignoring corrupt image/label: image file is truncated (49 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_122054.jpg: ignoring corrupt image/label: image file is truncated (109 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_122222.jpg: ignoring corrupt image/label: image file is truncated (18 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_122224.jpg: ignoring corrupt image/label: image file is truncated (8 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_122227.jpg: ignoring corrupt image/label: image file is truncated (95 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_122229.jpg: ignoring corrupt image/label: image file is truncated (111 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_122232.jpg: ignoring corrupt image/label: image file is truncated (127 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_122235.jpg: ignoring corrupt image/label: image file is truncated (68 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_122239.jpg: ignoring corrupt image/label: image file is truncated (8 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_122241.jpg: ignoring corrupt image/label: image file is truncated (25 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_122246.jpg: ignoring corrupt image/label: image file is truncated (118 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_122247.jpg: ignoring corrupt image/label: image file is truncated (62 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_122252.jpg: ignoring corrupt image/label: image file is truncated (32 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_122257.jpg: ignoring corrupt image/label: image file is truncated (25 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_122527.jpg: ignoring corrupt image/label: image file is truncated (35 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_122600.jpg: ignoring corrupt image/label: image file is truncated (96 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_152021.jpg: ignoring corrupt image/label: image file is truncated (18 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_152134.jpg: ignoring corrupt image/label: image file is truncated (65 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_152411.jpg: ignoring corrupt image/label: image file is truncated (16 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_152429.jpg: ignoring corrupt image/label: image file is truncated (6 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_152441.jpg: ignoring corrupt image/label: image file is truncated (75 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_152451.jpg: ignoring corrupt image/label: image file is truncated (127 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_152526.jpg: ignoring corrupt image/label: image file is truncated (25 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_152823.jpg: ignoring corrupt image/label: image file is truncated (69 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_152956.jpg: ignoring corrupt image/label: image file is truncated (137 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_153003.jpg: ignoring corrupt image/label: image file is truncated (19 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_153017.jpg: ignoring corrupt image/label: image file is truncated (48 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_153105.jpg: ignoring corrupt image/label: image file is truncated (44 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_153116.jpg: ignoring corrupt image/label: image file is truncated (154 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_153305.jpg: ignoring corrupt image/label: image file is truncated (147 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_153318.jpg: ignoring corrupt image/label: image file is truncated (89 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_153708.jpg: ignoring corrupt image/label: image file is truncated (54 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_153715.jpg: ignoring corrupt image/label: image file is truncated (57 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_153804.jpg: ignoring corrupt image/label: image file is truncated (22 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_154336.jpg: ignoring corrupt image/label: image file is truncated (144 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_154428.jpg: ignoring corrupt image/label: image file is truncated (49 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_154434.jpg: ignoring corrupt image/label: image file is truncated (32 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_154440.jpg: ignoring corrupt image/label: image file is truncated (31 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_154906.jpg: ignoring corrupt image/label: image file is truncated (13 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_154931.jpg: ignoring corrupt image/label: image file is truncated (71 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_155213.jpg: ignoring corrupt image/label: image file is truncated (78 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_155506.jpg: ignoring corrupt image/label: image file is truncated (124 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_155717.jpg: ignoring corrupt image/label: image file is truncated (58 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_155722.jpg: ignoring corrupt image/label: image file is truncated (133 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_155734.jpg: ignoring corrupt image/label: image file is truncated (31 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_155735.jpg: ignoring corrupt image/label: image file is truncated (139 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_155837.jpg: ignoring corrupt image/label: image file is truncated (115 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_155840.jpg: ignoring corrupt image/label: image file is truncated (21 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_155853.jpg: ignoring corrupt image/label: image file is truncated (146 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_160117.jpg: ignoring corrupt image/label: image file is truncated (15 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_160117_1.jpg: ignoring corrupt image/label: image file is truncated (33 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_160151.jpg: ignoring corrupt image/label: image file is truncated (127 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_160200.jpg: ignoring corrupt image/label: image file is truncated (127 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_160321.jpg: ignoring corrupt image/label: image file is truncated (3 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_160330.jpg: ignoring corrupt image/label: image file is truncated (105 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_160337.jpg: ignoring corrupt image/label: image file is truncated (59 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_160359.jpg: ignoring corrupt image/label: image file is truncated (63 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_160424.jpg: ignoring corrupt image/label: image file is truncated (106 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_160430.jpg: ignoring corrupt image/label: image file is truncated (13 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_160505.jpg: ignoring corrupt image/label: image file is truncated (53 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_160525.jpg: ignoring corrupt image/label: image file is truncated (89 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_160541.jpg: ignoring corrupt image/label: image file is truncated (95 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_160547.jpg: ignoring corrupt image/label: image file is truncated (22 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_160618.jpg: ignoring corrupt image/label: image file is truncated (44 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_160621.jpg: ignoring corrupt image/label: image file is truncated (80 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_160652.jpg: ignoring corrupt image/label: image file is truncated (40 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180816_160745.jpg: ignoring corrupt image/label: image file is truncated (2 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180817_091856.jpg: ignoring corrupt image/label: image file is truncated (45 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180817_091858.jpg: ignoring corrupt image/label: image file is truncated (9 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180817_091900.jpg: ignoring corrupt image/label: image file is truncated (95 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180817_092509.jpg: ignoring corrupt image/label: image file is truncated (59 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180817_092511.jpg: ignoring corrupt image/label: image file is truncated (54 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180817_092513.jpg: ignoring corrupt image/label: image file is truncated (31 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180817_092515.jpg: ignoring corrupt image/label: image file is truncated (95 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180817_092523.jpg: ignoring corrupt image/label: image file is truncated (15 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180817_092528.jpg: ignoring corrupt image/label: image file is truncated (53 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180817_092531.jpg: ignoring corrupt image/label: image file is truncated (49 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180817_092534.jpg: ignoring corrupt image/label: image file is truncated (83 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180817_092536.jpg: ignoring corrupt image/label: image file is truncated (57 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180817_092549.jpg: ignoring corrupt image/label: image file is truncated (62 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180817_092909.jpg: ignoring corrupt image/label: image file is truncated (40 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180817_092913.jpg: ignoring corrupt image/label: image file is truncated (61 bytes not processed)
# train: WARNING ⚠️ /content/train_data/images/train/IMG_20180817_092915.jpg: ignoring corrupt image/label: image file is truncated (32 bytes not processed)
# train: WARNING ⚠️ No labels found in /content/train_data/labels/train.cache. See https://github.com/ultralytics/yolov5/wiki/Train-Custom-Data
# train: WARNING ⚠️ Cache directory /content/train_data/labels is not writeable: [Errno 2] No such file or directory: '/content/train_data/labels/train.cache.npy'
# Traceback (most recent call last):
#   File "train.py", line 633, in <module>
#     main(opt)
#   File "train.py", line 527, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "train.py", line 187, in train
#     train_loader, dataset = create_dataloader(train_path,
#   File "/content/yolov5/utils/dataloaders.py", line 123, in create_dataloader
#     dataset = LoadImagesAndLabels(
#   File "/content/yolov5/utils/dataloaders.py", line 501, in __init__
#     assert nf > 0 or not augment, f'{prefix}No labels found in {cache_path}, can not start training. {HELP_URL}'
# AssertionError: train: No labels found in /content/train_data/labels/train.cache, can not start training. See https://github.com/ultralytics/yolov5/wiki/Train-Custom-Data

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source chigrtka.mp4
